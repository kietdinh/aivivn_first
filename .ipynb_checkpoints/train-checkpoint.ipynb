# %%
import pandas as pd
import numpy as np

# %%
import re

# %%
regep = re.compile(r"[-()\"#/@;:<>{}`+=~|.!?,]_*&^%$")
renumber = re.compile(r"\d+")

# %%
def transform(df):
    df['content'] = df['content'].apply(lambda x: str(x).lower())
    df['content'] = df['content'].apply(lambda x: renumber.sub('ddddd', x))
    df['content'] = df['content'].apply(lambda x: regep.sub('', x))
    df['content'] = df['content'].apply(lambda x: ' '.join([s for s in x.split(' ') if len(s) >= 3]))
    return df

# %%
data_train = pd.read_csv('train.csv')
data_train = data_train.sample(frac=1).reset_index(drop=True)

# %%
data_train.groupby('label').agg('count')
# Out:
#          id  content
# label
# 0      9280     9280
# 1      6807     6807

# %%
data_train = transform(data_train)

# %%
from collections import defaultdict

# %%
def query(df, text, show=0):
    label = defaultdict(int)
    for _, row in df.iterrows():
        if text in row['content']:
            label[row['label']] += 1
            if row['label'] == show:
                print(row['content'])
    print(label.items())

# %%
data_train.head(5)
# Out:
#              id                                            content  label
# 0  train_000942          dầu chó như rích biết phải hàng chuẩn nữa      1
# 1  train_001179             sản phẩm tốt chưa rách chưa dddddthang      1
# 2  train_002174  giày rất dởm nên mua. mới mang ddddd ngày bong...      1
# 3  train_001139  chất lượng sản phẩm tuyệt vời. vừa zin không c...      0
# 4  train_006201  that vong gê..mua dddddtuyp bán..made usa chữ ...      1

# %%
query(data_train, "hơi xấu")
# Out:
# chất lượng sản phẩm tuyệt vời đóng gói hơi xấu
# đồng rất đep với giá chưa tới dddddk thì tuyệt vời hết cơn mua hok kkk chỉ cái nhà vận chuyển lâu qá..kg phải lỗi shop tay hơi xấu nên đeo đẹp tay tròn đeo rất lúc đầu dây hơi cứng nhưng đeo vài lần mềm ngay
# móc khoá hơi rách bên trong nên nhìn hơi xấu nhưng cũng sao vẫn đẹp <ddddd mua của shop ddddd lần rồi lần nào cũng ưng đến rất ưng luôn. ủng shop dài dài
# thời gian giao hàng rất nhanh. che thóp được ddddd cái giống ảnh còn ddddd cái còn lại hơi xấu ddddd vẫn cho shop ddddd sao hàng chất lượng.
# chất lượng sản phẩm tuyệt vời nhưng điều mang bành hơi xấu còn lại rất tuyệt vời
# shop phục rất tốt thời gian giao hàng rất nhanh thời gian giao hàng rất nhanh đóng gói hơi xấu😁😁😁
# bọc hàng hơi xấukhá ẹp.
# hộp đựng giày hơi xấu nhưng giày thì
# mình mua bạn thôi thấy bạn mình khen sản phẩm đẹp lắm shop nhờ nhận được hàng chị ưng nhớ đánh giá cho nhé bạn mình chụp ảnh hơi xấu ngại đánh gia nhưng bạn vấn bảo chị đăng ksao đâu mấy bạn vấn rất đáng yêu. cho shop ddddd* nhé
# cắt hơi xấu
# gói hàng chắc chắn nhưng hơi xấu.
# dict_items([(0, 11)])

# %%
query(data_train, "đẹp")
# Out:
# chất lượng sản phẩm tuyệt vời đóng gói sản phẩm rất đẹp chắc chắn. form hơi to. bạn nào ddddd đặt ddddd vẫn vừa.
# chất lượng sản phẩm tuyệt vời. bút chì rất đẹp
# đóng gói sản phẩm rất đẹp chắc chắn giao hàg nhanh như ddddd cơn gió :)))) hôm trước đặt hôm sau nhận hàg luôn shop phục rất tốt
# giày đẹp !!!!
# chất lượng sản phẩm tuyệt vời đóng gói sản phẩm rất đẹp chắc chắn shop phục rất tốt rất đáng tiền thời gian giao hàng rất nhan
ất lượng sản phẩm tuyệt vời đóng gói sản phẩm rất đẹp chắc chắn shop phục rất tốt rất đáng tiền
# đóng gói sản phẩm rất đẹp chắc chắn.  shop phục rất tốt.. hàng auth thương. mask mùi thơm chịu. khi dụng trên môi thì hơi dính ddddd chút.
# mới nhận hàng nói chung dùng khá sướng nhưng tay minh hơi ngắn hay kích vào nút chỉnh tốc độ. khá đẹp. với giá này tốt lắm rùi..
# đóng gói sản phẩm rất đẹp chắc chắn. shop phục rất tốt. mua qua shopee nhiều đây lần đầu cảm thấy rất ưng dùng ủng shop dài dài. thời gian giao hàng rất nhanh
# đóng gói sản phẩm rất đẹp chắc chắn thời gian giao hàng hơi chậm
# rẻ- đẹp. kpit chất lượng sao
# hàng đẹp chuẩn ảnh
# đóng gói sản phẩm rất đẹp chắc chắn. đang dùng thử kết quả
# đóng gói sản phẩm rất đẹp chắc chắn.. thời gian giao hàng rất nhanh.. chưa uống thử nên chưa biết.
# đẹp
# chất lượng sản phẩm tuyệt vời đóng gói sản phẩm rất đẹp chắc chắn shop phục rất tốt rất đáng tiền thời gian giao hàng super nhanh chỉ ddddd tiếng thơi tới. chủ cho thêm ddddd miếng mask ddddd cục kẹo miniso mỗi lần tui nhìn cái mask nhớ tới mặt mặc chưa biết mặt bà. hehe
# đẹp lắm shop ơi.
# lên chân đẹp gọn chân. may mình đặt tăng lên ddddd nên rất vừa
# chất lượng sản phẩm tuyệt vời đóng gói sản phẩm rất đẹp chắc chắn son lên màu chuẩn chất son mịn mượt khô môi! rất ưng. ủng shop lần sau
# đóng gói sản phẩm rất đẹp chắc chắn. hàng với nhu cầu
# chất lượng sản phẩm tuyệt vời giày như hình màu còn đẹp hơn chụp ảnh. giao hàng hơi lâu
# chất lượng sản phẩm tuyệt vời đóng gói sản phẩm rất đẹp chắc chắn thời gian giao hàng rất nhanh shop phục rất tốt sách rất học
# dict_items([(0, 3611), (1, 258)])

# %%
n = len(data_train)
data_valid = data_train[:int(n*0.3)]
data_train = data_train[len(data_valid):]

# %%
data_test = pd.read_csv('test.csv')

# %%
data_test = transform(data_test)

# %%
data_test.head(5)
# Out:
#             id                                            content
# 0  test_000000                       chưa dùng thử nên chưa biết.
# 1  test_000001  không đáng tiềnvì ngay đợt sale nên mới mua nh...
# 2  test_000002     cám shop. đóng gói sản phẩm rất đẹp chắc chắn.
# 3  test_000003                     vải đẹp.phom oki luôn.quá ưng.
# 4  test_000004                           chuẩn hàng đóng gói đẹp.

# %%
len(data_train), len(data_valid), len(data_test)
# Out:
# (11261, 4826, 10981)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer

# %%
vectorizer = TfidfVectorizer(max_df=0.9,
#                              max_features=1000,
                             min_df=15,
                             use_idf=True,
                             ngram_range=(1,2))

# %%
X_train = vectorizer.fit_transform(data_train['content'])
X_valid = vectorizer.transform(data_valid['content'])
X_test = vectorizer.transform(data_test['content'])

# %%
X_train.shape
# Out:
# (11261, 2097)

# %%
vectorizer.get_feature_names()
# Out:
# ['ah',
#  'anh',
#  'auth',
#  'ba',
#  'balo',
#  'ban',
#  'ban đầu',
#  'bao',
#  'bao giờ',
#  'bao nhiêu',
#  'bay',
#  'bi',
#  'biet',
#  'biê',
#  'biến',
#  'biết',
#  'biết chất',
#  'biết phải',
#  'biệt',
#  'bo',
#  'bong',
#  'bung',
#  'buôn',
#  'buôn bán',
#  'buôn may',
#  'buồn',
#  'bài',
#  'bàn',
#  'bàn phím',
#  'bác',
#  'bám',
#  'bán',
#  'bán hàng',
#  'bán thịt',
#  'bán đắt',
#  'bánh',
#  'bánh ngon',
#  'báo',
#  'bây',
#  'bây giờ',
#  'bên',
#  'bên ngoài',
#  'bên shop',
#  'bên trong',
#  'bìa',
#  'bìa sách',
#  'bình',
#  'bình thường',
#  'bóc',
#  'bóng',
#  'bôi',
#  'bông',
#  'bút',
#  'băng',
#  'bạc',
#  'bạn',
#  'bạn mua',
#  'bạn nào',
#  'bạn nên',
#  'bản',
#  'bản thân',
#  'bảng',
#  'bảo',
#  'bảo hành',
#  'bấm',
#  'bất',
#  'bẩn',
#  'bật',
#  'bắt',
#  'bắt đầu',
#  'bằng',
#  'bền',
#  'bỉm',
#  'bịch',
#  'bọc',
#  'bột',
#  'bởi',
#  'bụi',
#  'bụng',
#  'bực',
#  'bực mình',
#  'ca',
#  'cai',
#  'cam',
#  'cam shop',
#  'camera',
#  'cao',
#  'cao hơn',
#  'cay',
#  'ch',
#  'chai',
#  'chat',
#  'chat luong',
#  'chay',
#  'che',
#  'check',
#  'chi',
#  'chi tiết',
#  'chia',
#  'chiếc',
#  'chiều',
#  'cho',
#  'cho bên',
#  'cho con',
#  'cho ddddd',
#  'cho khách',
#  'cho lắm',
#  'cho mình',
#  'cho người',
#  'cho shop',
#  'cho tôi',
#  'chu',
#  'chu đáo',
#  'chua',
#  'chung',
#  'chung rất',
#  'chuyên',
#  'chuyển',
#  'chuyện',
#  'chuẩn',
#  'chuẩn auth',
#  'chuột',
#  'chán',
#  'chát',
#  'cháy',
#  'châ',
#  'châ lươ',
#  'chân',
#  'chê',
#  'chì',
#  'chính',
#  'chính hãng',
#  'chó',
#  'chóng',
#  'chú',
#  'chúc',
#  'chúc shop',
#  'chút',
#  'chút nào',
#  'chă',
#  'chăm',
#  'chăm sóc',
#  'chăng',
#  'chơi',
#  'chưa',
#  'chưa bao',
#  'chưa biết',
#  'chưa dùng',
#  'chưa dụng',
#  'chưa nhận',
#  'chưa thấy',
#  'chưa đánh',
#  'chưa được',
#  'chạy',
#  'chả',
#  'chảy',
#  'chấp',
#  'chấp nhận',
#  'chất',
#  'chất liệu',
#  'chất lượng',
#  'chất son',
#  'chất vải',
#  'chất đẹp',
#  'chậm',
#  'chập',
#  'chật',
#  'chắc',
#  'chắc chắn',
#  'chắn',
#  'chắn chất',
#  'chắn giao',
#  'chắn hàng',
#  'chắn nhưng',
#  'chắn rất',
#  'chắn shop',
#  'chắn sản',
#  'chắn thời',
#  'chắn đóng',
#  'chẳng',
#  'chặt',
#  'chế',
#  'chết',
#  'chỉ',
#  'chỉ ddddd',
#  'chỉnh',
#  'chị',
#  'chị chủ',
#  'chịu',
#  'chọn',
#  'chống',
#  'chống nước',
#  'chống sốc',
#  'chốt',
#  'chỗ',
#  'chờ',
#  'chục',
#  'chụp',
#  'chụp ảnh',
#  'chủ',
#  'chủ shop',
#  'chứ',
#  'chứ không',
#  'chứ phải',
#  'chức',
#  'chức năng',
#  'chứng',
#  'chữ',
#  'co',
#  'code',
#  'coi',
#  'coi như',
#  'combo',
#  'con',
#  'cong',
#  'cu',
#  'cu ng',
#  'cua',
#  'cung',
#  'cute',
#  'cuối',
#  'cuối cùng',
#  'cuốn',
#  'cuốn này',
#  'cuốn sách',
#  'cuộc',
#  'cài',
#  'càng',
#  'các',
#  'các bạn',
#  'cách',
#  'cách làm',
#  'cách phục',
#  'cái',
#  'cái ddddd',
#  'cái hộp',
#  'cái này',
#  'cám',
#  'cám shop',
#  'cáo',
#  'cáp',
#  'cân',
#  'cân nhắc',
#  'câu',
#  'câu chuyện',
#  'cây',
#  'còn',
#  'còn chất',
#  'còn ddddd',
#  'còn hơn',
#  'còn lại',
#  'còn nguyên',
#  'còn tặng',
#  'còn được',
#  'còn ủng',
#  'có',
#  'công',
#  'công nghệ',
#  'cùng',
#  'căng',
#  'cũng',
#  'cũng chỉ',
#  'cũng khá',
#  'cũng không',
#  'cũng nhanh',
#  'cũng như',
#  'cũng rất',
#  'cũng thấy',
#  'cũng được',
#  'cũng đẹp',
#  'cơm',
#  'cưng',
#  'cường',
#  'cường lực',
#  'cạnh',
#  'cả',
#  'cảm',
#  'cảm giác',
#  'cảm nhận',
#  'cảm shop',
#  'cảm thấy',
#  'cấp',
#  'cấu',
#  'cầm',
#  'cần',
#  'cầu',
#  'cẩn',
#  'cẩn thận',
#  'cẩu',
#  'cẩu thả',
#  'cắm',
#  'cắt',
#  'cốc',
#  'cục',
#  'của',
#  'của mình',
#  'của người',
#  'của nấy',
#  'của shop',
#  'của tiki',
#  'của tác',
#  'của đấy',
#  'cứng',
#  'cửa',
#  'cửa hàng',
#  'cực',
#  'cực nhanh',
#  'cực đẹp',
#  'da',
#  'dai',
#  'dang',
#  'dao',
#  'dat',
#  'date',
#  'dau',
#  'day',
#  'dc',
#  'ddddd',
#  'ddddd bên',
#  'ddddd chiếc',
#  'ddddd cho',
#  'ddddd chút',
#  'ddddd chất',
#  'ddddd cái',
#  'ddddd câu',
#  'ddddd cây',
#  'ddddd ddddd',
#  'ddddd giao',
#  'ddddd gói',
#  'ddddd hôm',
#  'ddddd hộp',
#  'ddddd loại',
#  'ddddd lần',
#  'ddddd lớp',
#  'ddddd miếng',
#  'ddddd mua',
#  'ddddd màu',
#  'ddddd mình',
#  'ddddd mới',
#  'ddddd ngày',
#  'ddddd nhưng',
#  'ddddd năm',
#  'ddddd phút',
#  'ddddd rồi',
#  'ddddd sao',
#  'ddddd shop',
#  'ddddd size',
#  'ddddd sản',
#  'ddddd tháng',
#  'ddddd thì',
#  'ddddd thời',
#  'ddddd tiếng',
#  'ddddd tuần',
#  'ddddd vẫn',
#  'ddddd đôi',
#  'ddddd đến',
#  'dddddc',
#  'dddddg',
#  'dddddgb',
#  'dddddh',
#  'dddddk',
#  'dddddk thì',
#  'dddddkg',
#  'dddddp',
#  'ddddds',
#  'dddddsao',
#  'deal',
#  'den',
#  'dep',
#  'diễn',
#  'do',
#  'doi',
#  'dong',
#  'dong goi',
#  'du',
#  'du ng',
#  'dung',
#  'dung lượng',
#  'duoc',
#  'dài',
#  'dài dài',
#  'dành',
#  'dành cho',
#  'dày',
#  'dày dặn',
#  'dám',
#  'dám mua',
#  'dán',
#  'dáng',
#  'dây',
#  'dây giày',
#  'dép',
#  'dép đẹp',
#  'dính',
#  'dòng',
#  'dùm',
#  'dùng',
#  'dùng chưa',
#  'dùng ddddd',
#  'dùng nên',
#  'dùng rất',
#  'dùng thì',
#  'dùng thấy',
#  'dùng thử',
#  'dùng tốt',
#  'dùng được',
#  'dưới',
#  'dưỡng',
#  'dạng',
#  'dấu',
#  'dầu',
#  'dẫn',
#  'dặn',
#  'dẹp',
#  'dẻo',
#  'dịch',
#  'dỏm',
#  'dụng',
#  'dụng nên',
#  'dụng được',
#  'em',
#  'fake',
#  'form',
#  'full',
#  'ghi',
#  'ghi chú',
#  'ghê',
#  'gia',
#  'gian',
#  'gian giao',
#  'giao',
#  'giao cho',
#  'giao ddddd',
#  'giao ha',
#  'giao hang',
#  'giao hàng',
#  'giao không',
#  'giao màu',
#  'giao nhanh',
#  'giao nhầm',
#  'giao sai',
#  'giao thiếu',
#  'giao đúng',
#  'giay',
#  'gio',
#  'giong',
#  'giày',
#  'giày hơi',
#  'giày rất',
#  'giày đẹp',
#  'giá',
#  'giá cao',
#  'giá chất',
#  'giá ddddd',
#  'giá dddddk',
#  'giá hợp',
#  'giá lại',
#  'giá này',
#  'giá quá',
#  'giá thành',
#  'giá thì',
#  'giá tiền',
#  'giá tốt',
#  'giác',
#  'giác như',
#  'giáo',
#  'giòn',
#  'giúp',
#  'giả',
#  'giải',
#  'giải quyết',
#  'giảm',
#  'giảm giá',
#  'giản',
#  'giấy',
#  'giầy',
#  'giầy đẹp',
#  'giật',
#  'giặt',
#  'giống',
#  'giống hình',
#  'giống nhau',
#  'giống như',
#  'giống trong',
#  'giống với',
#  'giới',
#  'giới thiệu',
#  'giờ',
#  'giờ mua',
#  'giữ',
#  'giữa',
#  'go',
#  'goi',
#  'good',
#  'gui',
#  'gái',
#  'gây',
#  'gãy',
#  'gì',
#  'góc',
#  'gói',
#  'gói chắc',
#  'gói cẩn',
#  'gói hàng',
#  'gói rất',
#  'gói sản',
#  'gói đẹp',
#  'góp',
#  'gương',
#  'gấp',
#  'gần',
#  'gần ddddd',
#  'gắn',
#  'gặp',
#  'gọi',
#  'gọi điện',
#  'gọn',
#  'gốc',
#  'gởi',
#  'gửi',
#  'gửi cho',
#  'gửi ddddd',
#  'gửi hàng',
#  'gửi lại',
#  'gửi màu',
#  'ha',
#  'ha ng',
#  'hag',
#  'hai',
#  'ham',
#  'hang',
#  'hang nhanh',
#  'hay',
#  'hay không',
#  'hay sao',
#  'het',
#  'hi',
#  'hi nh',
#  'hic',
#  'hihi',
#  'hinh',
#  'hiểu',
#  'hiểu sao',
#  'hiện',
#  'hiện tại',
#  'hiệu',
#  'hiệu quả',
#  'hoa',
#  'hoi',
#  'hok',
#  'hoài',
#  'hoàn',
#  'hoàn thiện',
#  'hoàn tiền',
#  'hoàn toàn',
#  'hoàng',
#  'hoá',
#  'hoạt',
#  'hoạt động',
#  'hoặc',
#  'huhu',
#  'hàg',
#  'hài',
#  'hài lòng',
#  'hàn',
#  'hàng',
#  'hàng auth',
#  'hàng cho',
#  'hàng chuẩn',
#  'hàng chính',
#  'hàng chưa',
#  'hàng chất',
#  'hàng chậm',
#  'hàng cũng',
#  'hàng cẩn',
#  'hàng của',
#  'hàng cực',
#  'hàng ddddd',
#  'hàng dùng',
#  'hàng giao',
#  'hàng giả',
#  'hàng giống',
#  'hàng hơi',
#  'hàng khá',
#  'hàng không',
#  'hàng kém',
#  'hàng lâu',
#  'hàng lại',
#  'hàng lỗi',
#  'hàng mình',
#  'hàng mới',
#  'hàng ngày',
#  'hàng nhanh',
#  'hàng nhái',
#  'hàng như',
#  'hàng nhưng',
#  'hàng nhận',
#  'hàng phải',
#  'hàng quá',
#  'hàng rất',
#  'hàng rồi',
#  'hàng shop',
#  'hàng siêu',
#  'hàng thiếu',
#  'hàng thì',
#  'hàng thật',
#  'hàng trước',
#  'hàng tâm',
#  'hàng tốt',
#  'hàng đóng',
#  'hàng đúng',
#  'hàng đặt',
#  'hàng đẹp',
#  'hành',
#  'hãng',
#  'hãy',
#  'hình',
#  'hình chất',
#  'hình giao',
#  'hình như',
#  'hình nhưng',
#  'hình rất',
#  'hình thức',
#  'hình đẹp',
#  'hình ảnh',
#  'hóa',
#  'hô',
#  'hôi',
#  'hôm',
#  'hôm nay',
#  'hôm qua',
#  'hôm sau',
#  'hút',
#  'hơi',
#  'hơi chậm',
#  'hơi cứng',
#  'hơi khó',
#  'hơi lâu',
#  'hơi mỏng',
#  'hơi nhỏ',
#  'hơi rộng',
#  'hơi thất',
#  'hơn',
#  'hơn ddddd',
#  'hơn mong',
#  'hơn mình',
#  'hơn nhiều',
#  'hơn nữa',
#  'hơn trong',
#  'hơn với',
#  'hương',
#  'hướng',
#  'hướng dẫn',
#  'hại',
#  'hạn',
#  'hạn dụng',
#  'hạt',
#  'hấp',
#  'hấp dẫn',
#  'hận',
#  'hẳn',
#  'hẹn',
#  'hết',
#  'hết ddddd',
#  'hết hàng',
#  'hết hạn',
#  'hết pin',
#  'học',
#  'hỏi',
#  'hỏi shop',
#  'hỏng',
#  'hối',
#  'hối hận',
#  'hồi',
#  'hồng',
#  'hội',
#  'hộp',
#  'hộp móp',
#  'hộp đựng',
#  'hợp',
#  'hợp giá',
#  'hợp với',
#  'hứa',
#  'ipddddd',
#  'iphone',
#  'kem',
#  'keo',
#  'kha',
#  'khen',
#  'khi',
#  'khi dùng',
#  'khi giao',
#  'khi mua',
#  'khi mình',
#  'khi nhận',
#  'khi nào',
#  'khi đặt',
#  'khi đọc',
#  'khiến',
#  'kho',
#  'khong',
#  'khoảng',
#  'khoảng ddddd',
#  'khui',
#  'khuyên',
#  'khuyến',
#  'khá',
#  'khá nhanh',
#  'khá nhiều',
#  'khá tốt',
#  'khá đẹp',
#  'khác',
#  'khác nhau',
#  'khác với',
#  'khách',
#  'khách hàng',
#  'khâu',
#  'khó',
#  'khó chịu',
#  'khóa',
#  'khô',
#  'khô môi',
#  'không',
#  'không bao',
#  'không biết',
#  'không chắc',
#  'không còn',
#  'không dám',
#  'không dùng',
#  'không dụng',
#  'không giống',
#  'không hiểu',
#  'không hài',
#  'không hợp',
#  'không mua',
#  'không muốn',
#  'không như',
#  'không nhận',
#  'không nên',
#  'không phải',
#  'không thích',
#  'không thấy',
#  'không thể',
#  'không trả',
#  'không tốt',
#  'không vào',
#  'không vừa',
#  'không đáng',
#  'không đúng',
#  'không được',
#  'không đẹp',
#  'khăn',
#  'khẩu',
#  'khắc',
#  'khỏi',
#  'khủng',
#  'kia',
#  'kim',
#  'kinh',
#  'kinh khủng',
#  'kiến',
#  'kiểm',
#  'kiểm tra',
#  'kiểu',
#  'kiểu dáng',
#  'kiểu này',
#  'kiện',
#  'ko',
#  'kèm',
#  'kèm theo',
#  'kém',
#  'kém chất',
#  'kém giao',
#  'kém hàng',
#  'kém không',
#  'kém mua',
#  'kém rất',
#  'kém shop',
#  'kém thời',
#  'kém đóng',
#  'kéo',
#  'kêu',
#  'kích',
#  'kích thước',
#  'kính',
#  'kĩ',
#  'kẹo',
#  'kết',
#  'kết nối',
#  'kết quả',
#  'kỹ',
#  'la',
#  'lai',
#  'lam',
#  'lan',
#  'lau',
#  'led',
#  'lem',
#  'len',
#  'like',
#  'linh',
#  'liên',
#  'liên lạc',
#  'liền',
#  'liệu',
#  'loa',
#  'loi',
#  'long',
#  'loại',
#  'loại khác',
#  'lum',
#  'lun',
#  'lung',
#  'luon',
#  'luong',
#  'luôn',
#  'luôn ddddd',
#  'làm',
#  'làm mình',
#  'làm như',
#  'làm sao',
#  'làm việc',
#  'lâ',
#  'lâu',
#  'lâu dài',
#  'lên',
#  'lên ddddd',
#  'lên màu',
#  'lòng',
#  'lòng lắm',
#  'lòng sản',
#  'lòng với',
#  'lót',
#  'lông',
#  'lúc',
#  'lúc nhận',
#  'lúc nào',
#  'lúc đầu',
#  'lý',
#  'lă',
#  'lưng',
#  'lưu',
#  'lươ',
#  'lươ ng',
#  'lương',
#  'lượng',
#  'lượng chưa',
#  'lượng hàng',
#  'lượng kém',
#  'lượng như',
#  'lượng quá',
#  'lượng rất',
#  'lượng sản',
#  'lượng thì',
#  'lượng tuyệt',
#  'lượng tốt',
#  'lạc',
#  'lại',
#  'lại cho',
#  'lại còn',
#  'lại ddddd',
#  'lại giao',
#  'lại gửi',
#  'lại hàng',
#  'lại không',
#  'lại rất',
#  'lại shop',
#  'lại thì',
#  'lại được',
#  'lạnh',
#  'lấy',
#  'lấy hàng',
#  'lầm',
#  'lần',
#  'lần ddddd',
#  'lần nào',
#  'lần này',
#  'lần rồi',
#  'lần sau',
#  'lần thứ',
#  'lần đầu',
#  'lẫn',
#  'lắm',
#  'lắm luôn',
#  'lắm nha',
#  'lắm nhé',
#  'lắm nhưng',
#  'lắm shop',
#  'lắp',
#  'lẻo',
#  'lệch',
#  'lịch',
#  'lỏng',
#  'lỏng lẻo',
#  'lỗi',
#  'lộn',
#  'lớn',
#  'lớp',
#  'lời',
#  'lợi',
#  'lừa',
#  'lừa đảo',
#  'lựa',
#  'lực',
#  'ma',
#  'mai',
#  'man',
#  'mang',
#  'mang chân',
#  'mask',
#  'mat',
#  'mau',
#  'max',
#  'may',
#  'may bán',
#  'mi',
#  'mi nh',
#  'minh',
#  'miêu',
#  'miếng',
#  'miếng dán',
#  'miệng',
#  'moi',
#  'mong',
#  'mong shop',
#  'mong đợi',
#  'mua',
#  'mua cho',
#  'mua cái',
#  'mua của',
#  'mua ddddd',
#  'mua dùng',
#  'mua hàng',
#  'mua không',
#  'mua lại',
#  'mua lần',
#  'mua màu',
#  'mua nhiều',
#  'mua shop',
#  'mua sản',
#  'mua thêm',
#  'mua thì',
#  'mua tiếp',
#  'mua được',
#  'muốn',
#  'muốn mua',
#  'muốn đổi',
#  'mà',
#  'màn',
#  'màn hình',
#  'màu',
#  'màu ddddd',
#  'màu hồng',
#  'màu lên',
#  'màu rất',
#  'màu son',
#  'màu sắc',
#  'màu trắng',
#  'màu vàng',
#  'màu xanh',
#  'màu đen',
#  'màu đẹp',
#  'mác',
#  'mái',
#  'mát',
#  'máy',
#  'máy chạy',
#  'máy dùng',
#  'mâ',
#  'mãi',
#  'mèo',
#  'méo',
#  'mình',
#  'mình chưa',
#  'mình cũng',
#  'mình cảm',
#  'mình ddddd',
#  'mình dùng',
#  'mình không',
#  'mình mua',
#  'mình mình',
#  'mình mới',
#  'mình nghĩ',
#  'mình nhận',
#  'mình rất',
#  'mình thì',
#  'mình thích',
#  'mình thấy',
#  'mình tưởng',
#  'mình từng',
#  'mình vẫn',
#  'mình vừa',
#  'mình đặt',
#  'mình ủng',
#  'móc',
#  'món',
#  'móp',
#  'móp méo',
#  'môi',
#  'mùi',
#  ...]

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import f1_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from imblearn.ensemble import BalancedBaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
import lightgbm

# %%
clfs = {
    "RF": RandomForestClassifier(n_estimators=200, min_samples_leaf=2, max_depth=30, max_features=0.7, random_state=42, n_jobs=-1),
    "GB": GradientBoostingClassifier(n_estimators=200, min_samples_split=2, max_depth=10, max_features=0.7, random_state=111),
    "BB": BalancedBaggingClassifier(n_estimators=200, max_features=0.7, max_samples=0.7, random_state=111),
    "LR": LogisticRegression(penalty='l2', C=1.0),
}

# %%
for name, clf in clfs.items():
    y_true = data_train['label']
    clf.fit(X_train, y_true)
    y_pred = clf.predict(X_train)
    
    print("F1", f1_score(y_true, y_pred))
    print("CM", confusion_matrix(y_true, y_pred))
    
    y_true = data_valid['label']
    y_pred = clf.predict(X_valid)
    
    print("F1", f1_score(y_true, y_pred))
    print("CM", confusion_matrix(y_true, y_pred))
# Out:
# F1 0.7948740301630198
# CM [[4349 2206]
#  [ 147 4559]]
# F1 0.7855575503690405
# CM [[1782  943]
#  [ 132 1969]]
# F1 0.8933410762679056
# CM [[5544 1011]
#  [  91 4615]]
# F1 0.8119750161533492
# CM [[2068  657]
#  [ 216 1885]]
# F1 0.9001165954139136
# CM [[5601  954]
#  [  74 4632]]
# F1 0.812771503040834
# CM [[2093  632]
#  [ 230 1871]]
# F1 0.8453022435583424
# CM [[5368 1187]
#  [ 392 4314]]
# F1 0.8216097023153252
# CM [[2154  571]
#  [ 238 1863]]
# /home/kietdv/.local/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
parameters = {
    'application': 'binary',
    'objective': 'binary',
    'metric': 'auc',
    'is_unbalance': 'true',
    'boosting': 'gbdt',
    'num_leaves': 31,
    'feature_fraction': 0.7,
    'bagging_fraction': 0.5,
    'bagging_freq': 30,
    'learning_rate': 0.05,
    'verbose': 0,
    'n_estimators': 200,
}

# %%
train_data = lightgbm.Dataset(X_train, label=data_train['label'])
valid_data = lightgbm.Dataset(X_valid, label=data_valid['label'])

# %%
model = lightgbm.train(parameters,
                       train_data,
                       valid_sets=valid_data,
                       num_boost_round=5000,
                       early_stopping_rounds=200)
# Out:
# /home/kietdv/.local/lib/python3.6/site-packages/lightgbm/engine.py:118: UserWarning: Found `n_estimators` in params. Will use it instead of argument
#   warnings.warn("Found `{}` in params. Will use it instead of argument".format(alias))
# [1]	valid_0's auc: 0.829816
# Training until validation scores don't improve for 200 rounds.
# [2]	valid_0's auc: 0.851207
# [3]	valid_0's auc: 0.859397
# [4]	valid_0's auc: 0.86039
# [5]	valid_0's auc: 0.862165
# [6]	valid_0's auc: 0.864201
# [7]	valid_0's auc: 0.866228
# [8]	valid_0's auc: 0.8668
# [9]	valid_0's auc: 0.86771
# [10]	valid_0's auc: 0.869181
# [11]	valid_0's auc: 0.871862
# [12]	valid_0's auc: 0.872396
# [13]	valid_0's auc: 0.872277
# [14]	valid_0's auc: 0.87243
# [15]	valid_0's auc: 0.873285
# [16]	valid_0's auc: 0.873923
# [17]	valid_0's auc: 0.874648
# [18]	valid_0's auc: 0.874828
# [19]	valid_0's auc: 0.875092
# [20]	valid_0's auc: 0.875472
# [21]	valid_0's auc: 0.875895
# [22]	valid_0's auc: 0.876287
# [23]	valid_0's auc: 0.876419
# [24]	valid_0's auc: 0.877104
# [25]	valid_0's auc: 0.877746
# [26]	valid_0's auc: 0.877689
# [27]	valid_0's auc: 0.878
# [28]	valid_0's auc: 0.877794
# [29]	valid_0's auc: 0.877927
# [30]	valid_0's auc: 0.87868
# [31]	valid_0's auc: 0.879989
# [32]	valid_0's auc: 0.881516
# [33]	valid_0's auc: 0.883058
# [34]	valid_0's auc: 0.884583
# [35]	valid_0's auc: 0.885587
# [36]	valid_0's auc: 0.885707
# [37]	valid_0's auc: 0.88672
# [38]	valid_0's auc: 0.886744
# [39]	valid_0's auc: 0.886689
# [40]	valid_0's auc: 0.887361
# [41]	valid_0's auc: 0.88721
# [42]	valid_0's auc: 0.887063
# [43]	valid_0's auc: 0.887397
# [44]	valid_0's auc: 0.888129
# [45]	valid_0's auc: 0.888745
# [46]	valid_0's auc: 0.88895
# [47]	valid_0's auc: 0.889671
# [48]	valid_0's auc: 0.890467
# [49]	valid_0's auc: 0.890335
# [50]	valid_0's auc: 0.890442
# [51]	valid_0's auc: 0.890574
# [52]	valid_0's auc: 0.890816
# [53]	valid_0's auc: 0.89115
# [54]	valid_0's auc: 0.891412
# [55]	valid_0's auc: 0.891868
# [56]	valid_0's auc: 0.892692
# [57]	valid_0's auc: 0.893077
# [58]	valid_0's auc: 0.893358
# [59]	valid_0's auc: 0.893408
# [60]	valid_0's auc: 0.893486
# [61]	valid_0's auc: 0.894985
# [62]	valid_0's auc: 0.89533
# [63]	valid_0's auc: 0.896046
# [64]	valid_0's auc: 0.896085
# [65]	valid_0's auc: 0.895929
# [147]	valid_0's auc: 0.907039
# [148]	valid_0's auc: 0.907041
# [149]	valid_0's auc: 0.907069
# [150]	valid_0's auc: 0.907109
# [151]	valid_0's auc: 0.907616
# [152]	valid_0's auc: 0.907726
# [153]	valid_0's auc: 0.907324
# [154]	valid_0's auc: 0.907462
# [155]	valid_0's auc: 0.907459
# [156]	valid_0's auc: 0.907522
# [157]	valid_0's auc: 0.907284
# [158]	valid_0's auc: 0.9073
# [159]	valid_0's auc: 0.90731
# [160]	valid_0's auc: 0.907382
# [161]	valid_0's auc: 0.907322
# [162]	valid_0's auc: 0.907365
# [163]	valid_0's auc: 0.907274
# [164]	valid_0's auc: 0.907393
# [165]	valid_0's auc: 0.907368
# [166]	valid_0's auc: 0.907301
# [167]	valid_0's auc: 0.907411
# [168]	valid_0's auc: 0.907319
# [169]	valid_0's auc: 0.907557
# [170]	valid_0's auc: 0.907441
# [171]	valid_0's auc: 0.907481
# [172]	valid_0's auc: 0.907467
# [173]	valid_0's auc: 0.907453
# [174]	valid_0's auc: 0.907251
# [175]	valid_0's auc: 0.907351
# [176]	valid_0's auc: 0.907567
# [177]	valid_0's auc: 0.907334
# [178]	valid_0's auc: 0.907322
# [179]	valid_0's auc: 0.907389
# [180]	valid_0's auc: 0.907404
# [181]	valid_0's auc: 0.90712
# [182]	valid_0's auc: 0.907349
# [183]	valid_0's auc: 0.907352
# [184]	valid_0's auc: 0.907413
# [185]	valid_0's auc: 0.907568
# [186]	valid_0's auc: 0.90774
# [187]	valid_0's auc: 0.908041
# [188]	valid_0's auc: 0.908018
# [189]	valid_0's auc: 0.908356
# [190]	valid_0's auc: 0.90844
# [191]	valid_0's auc: 0.908731
# [192]	valid_0's auc: 0.908624
# [193]	valid_0's auc: 0.908703
# [194]	valid_0's auc: 0.90891
# [195]	valid_0's auc: 0.908996
# [196]	valid_0's auc: 0.909372
# [197]	valid_0's auc: 0.909313
# [198]	valid_0's auc: 0.909239
# [199]	valid_0's auc: 0.909517
# [200]	valid_0's auc: 0.909418
# Did not meet early stopping. Best iteration is:
# [199]	valid_0's auc: 0.909517

# %%
# clfs['gbm'] = model
# del clfs['gbm']

# %%
df = pd.DataFrame()
for name, clf in clfs.items():
    df[name] = [a[1] for a in clf.predict_proba(X_valid)]

# %%
tmp = model.predict(X_valid)
# rows = []
# for b in tmp:
#     rows.append([1-b, b])
df['bgm'] = [b for b in tmp]

# %%
df.head(5)
# Out:
#          RF        GB        BB        LR       bgm
# 0  0.577164  0.512147  0.579459  0.441229  0.517196
# 1  0.577164  0.534796  0.583300  0.440432  0.611703
# 2  0.700684  0.931226  0.970000  0.959046  0.987200
# 3  0.000000  0.067422  0.010000  0.046514  0.011452
# 4  0.077579  0.187728  0.122748  0.146422  0.082702

# %%
len(df)
# Out:
# 4826

# %%
df['final'] = (df['RF'] + df['GB'] + df['BB'] + df['LR'] + df['bgm'])/5

# %%
df.head()
# Out:
#          RF        GB        BB        LR       bgm     final
# 0  0.577164  0.512147  0.579459  0.441229  0.517196  0.525439
# 1  0.577164  0.534796  0.583300  0.440432  0.611703  0.549479
# 2  0.700684  0.931226  0.970000  0.959046  0.987200  0.909631
# 3  0.000000  0.067422  0.010000  0.046514  0.011452  0.027077
# 4  0.077579  0.187728  0.122748  0.146422  0.082702  0.123436

# %%
submit = pd.DataFrame(columns=['id', 'label'])
submit['id'] = data_valid['id']
submit['label'] = df['final']

# %%
# submit['label'] = submit['label'].apply(lambda x: int(np.argmax(x)))
submit['label'] = submit['label'].apply(lambda x: 1 if float(x) >= 0.5 else 0)

# %%
submit.head(5)
# Out:
#              id  label
# 0  train_015745      1
# 1  train_002006      1
# 2  train_000504      1
# 3  train_006811      0
# 4  train_001824      0

# %%
submit.to_csv('submition_newest.csv', index=False)

# %%
print("F1", f1_score(data_valid['label'], submit['label']))
print("CM", confusion_matrix(data_valid['label'], submit['label']))
# Out:
# F1 0.8199871877001921
# CM [[2063  662]
#  [ 181 1920]]

# %%
len(submit)
# Out:
# 11261

# %%
X_req = df.drop('final', axis=1)

# %%
X_req.head(5)
# Out:
#          RF        GB     BB        LR       bgm
# 0  0.003993  0.006320  0.000  0.001589  0.002405
# 1  0.003993  0.008717  0.000  0.003250  0.002240
# 2  0.990004  0.981680  0.975  0.977008  0.986780
# 3  0.976417  0.981942  0.990  0.894421  0.965323
# 4  0.968781  0.992424  0.985  0.971136  0.996490

# %%
len(X_req)
# Out:
# 11261

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
lr = LinearRegression()

# %%
lr.fit(X_req, data_train['label'])
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
lr.coef_
# Out:
# array([-0.51230281,  1.14304829,  1.26192237, -0.41513897, -0.39857753])

# %%
y_pred = lr.predict(X_req)

# %%
mean_squared_error(data_train['label'], y_pred)
# Out:
# 0.014536341611988997

# %%
data_train['label']
# Out:
# 4826     0
# 4827     0
# 4828     1
# 4829     1
# 4830     1
# 4831     0
# 4832     1
# 4833     0
# 4834     0
# 4835     1
# 4836     0
# 4837     0
# 4838     1
# 4839     0
# 4840     1
# 4841     1
# 4842     0
# 4843     0
# 4844     1
# 4845     1
# 4846     0
# 4847     0
# 4848     1
# 4849     0
# 4850     0
# 4851     0
# 4852     0
# 4853     1
# 4854     0
# 4855     1
#         ..
# 16057    1
# 16058    0
# 16059    0
# 16060    1
# 16061    1
# 16062    0
# 16063    0
# 16064    0
# 16065    0
# 16066    1
# 16067    0
# 16068    0
# 16069    0
# 16070    0
# 16071    1
# 16072    0
# 16073    0
# 16074    1
# 16075    1
# 16076    0
# 16077    1
# 16078    0
# 16079    1
# 16080    0
# 16081    1
# 16082    0
# 16083    0
# 16084    0
# 16085    0
# 16086    1
# Name: label, Length: 11261, dtype: int64

# %%
X_req['y'] = data_train.reset_index()['label']

# %%
X_req.head(5)
# Out:
#          RF        GB     BB        LR       bgm  y
# 0  0.003993  0.006320  0.000  0.001589  0.002405  0
# 1  0.003993  0.008717  0.000  0.003250  0.002240  0
# 2  0.990004  0.981680  0.975  0.977008  0.986780  1
# 3  0.976417  0.981942  0.990  0.894421  0.965323  1
# 4  0.968781  0.992424  0.985  0.971136  0.996490  1

# %%
X_req.to_csv('linear_train.csv', index=False)
